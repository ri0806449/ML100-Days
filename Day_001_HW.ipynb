# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum(abs(y - yp)**2) / len(y)
    return mse
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.231

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 178.808
# The Mean absolute error is 10.432

# %% [markdown]
# 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 我於Kaggle的dataset中挑選以下資料：Suicide Rates Overview 1985 to 2016
# 1. 你選的這組資料為何重要
#     現代人所需承受的壓力將隨著科技進步所衍生層出不窮的問題而增加，試圖探究影響自殺率變化之相關因素以及其相關程度，對於心理健康的助益與社會事
#     件的預防皆有所幫助。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     資料來源：
#     HDRO calculations based on data from UNDESA (2017a), UNESCO Institute for Statistics (2018), United Nations Statistics Division
#     (2018b), World Bank (2018b), Barro and Lee (2016) and IMF (2018).
#     WHO.
#     由世界衛生組織的國家提供每年的調查。
#
# 3. 蒐集而來的資料型態為何
#     型態以表格呈現，包含各項變量。
#
# 4. 這組資料想解決的問題如何評估
#     可以將各國的自殺率與經濟指標做相關分析，並就不同的國家、文化、時間，分析其相關之變化。
#
# 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     我的假設是：不同的時段（通勤時段、假日vs平日等等）及上車地點兩個因素是影響載客車隊業績最需關注的變項
#     歸納出一天/一星期之中何時的的載客量最多，以及何地最易載到客人，再針對上述資料的統整進一步修正載客策略。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     資料的蒐集為先前載客紀錄與長、短程相關資料。
#
# 3. 蒐集而來的資料型態為何
#     為表格形式，包含時間、地點、獲利（長、短程）。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     依照不同時段調整出車量，減少不必要之油耗，同時增加載客需求量較大的時段之出車量，增加收益，並根據提供之上車地點統計，上車地點次數高者派出較多車輛於附近備車。
#     修正載客策略後，評估其獲利成果是否達到目標。
